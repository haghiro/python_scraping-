# %%
from assets import models
import pandas as pd

from assets.database import db_session

# %%
df = pd.read_csv('assets/data.csv')

# %%
df.head()
# Out:
#         date  subscribers  reviews
# 0  2019/1/17         2671      194
# 1  2019/1/18         2671      195
# 2  2019/1/19         2674      197
# 3  2019/1/20         2685      199
# 4  2019/1/21         2695      199

# %%
df.iloc[0,0]
# Out:
# '2019/1/17'

# %%
import datetime

# %%
date = datetime.datetime.strptime(df.iloc[0,0],'%Y/%m/%d').date()
date
# Out:
# datetime.date(2019, 1, 17)

# %%
for index, _df in df.iterrows():
    date = datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
    row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
    db_session.add(row)
db_session.commit()
# Out:
# 2020-10-21 22:06:41,334 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-10-21 22:06:41,335 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-21 22:06:41,336 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-10-21 22:06:41,337 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-21 22:06:41,338 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-10-21 22:06:41,344 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,345 INFO sqlalchemy.engine.base.Engine ('2019-01-17', 2671, 194, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,346 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,347 INFO sqlalchemy.engine.base.Engine ('2019-01-18', 2671, 195, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,348 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,349 INFO sqlalchemy.engine.base.Engine ('2019-01-19', 2674, 197, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,350 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,351 INFO sqlalchemy.engine.base.Engine ('2019-01-20', 2685, 199, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,352 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,352 INFO sqlalchemy.engine.base.Engine ('2019-01-21', 2695, 199, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,353 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,354 INFO sqlalchemy.engine.base.Engine ('2019-01-22', 2701, 200, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,355 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,355 INFO sqlalchemy.engine.base.Engine ('2019-01-23', 2710, 200, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,356 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,357 INFO sqlalchemy.engine.base.Engine ('2019-01-24', 2718, 201, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,358 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,359 INFO sqlalchemy.engine.base.Engine ('2019-01-25', 2722, 201, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,360 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,361 INFO sqlalchemy.engine.base.Engine ('2019-01-26', 2725, 201, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,362 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,363 INFO sqlalchemy.engine.base.Engine ('2019-01-27', 2734, 202, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,364 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,365 INFO sqlalchemy.engine.base.Engine ('2019-01-28', 2753, 204, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,367 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,368 INFO sqlalchemy.engine.base.Engine ('2019-01-29', 2773, 206, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,369 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,370 INFO sqlalchemy.engine.base.Engine ('2019-01-30', 2785, 208, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,372 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,373 INFO sqlalchemy.engine.base.Engine ('2019-01-31', 2803, 210, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,374 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,375 INFO sqlalchemy.engine.base.Engine ('2019-02-01', 2845, 211, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,376 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,377 INFO sqlalchemy.engine.base.Engine ('2019-02-02', 2847, 213, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,378 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,379 INFO sqlalchemy.engine.base.Engine ('2019-02-03', 2847, 213, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,380 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,380 INFO sqlalchemy.engine.base.Engine ('2019-02-04', 2851, 217, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,381 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,382 INFO sqlalchemy.engine.base.Engine ('2019-02-05', 2852, 218, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,383 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,384 INFO sqlalchemy.engine.base.Engine ('2019-02-06', 2857, 219, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,385 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,385 INFO sqlalchemy.engine.base.Engine ('2019-02-07', 2861, 220, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,386 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,387 INFO sqlalchemy.engine.base.Engine ('2019-02-08', 2865, 222, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,388 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,389 INFO sqlalchemy.engine.base.Engine ('2019-02-09', 2870, 224, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,390 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,391 INFO sqlalchemy.engine.base.Engine ('2019-02-10', 2875, 224, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,392 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,393 INFO sqlalchemy.engine.base.Engine ('2019-02-11', 2892, 227, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,394 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,395 INFO sqlalchemy.engine.base.Engine ('2019-02-12', 2906, 229, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,396 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,396 INFO sqlalchemy.engine.base.Engine ('2019-02-13', 2919, 229, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,397 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,399 INFO sqlalchemy.engine.base.Engine ('2019-02-14', 2942, 231, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,400 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,401 INFO sqlalchemy.engine.base.Engine ('2019-02-15', 2974, 232, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,402 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,403 INFO sqlalchemy.engine.base.Engine ('2019-02-16', 2977, 234, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,404 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,404 INFO sqlalchemy.engine.base.Engine ('2019-02-17', 2978, 234, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,405 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,407 INFO sqlalchemy.engine.base.Engine ('2019-02-18', 2981, 234, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,408 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,409 INFO sqlalchemy.engine.base.Engine ('2019-02-19', 2983, 234, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,410 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,410 INFO sqlalchemy.engine.base.Engine ('2019-02-20', 2984, 237, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,411 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,412 INFO sqlalchemy.engine.base.Engine ('2019-02-21', 2987, 239, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,413 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,414 INFO sqlalchemy.engine.base.Engine ('2019-02-22', 2989, 239, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,415 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,416 INFO sqlalchemy.engine.base.Engine ('2019-02-23', 2993, 241, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,417 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,418 INFO sqlalchemy.engine.base.Engine ('2019-02-24', 2995, 241, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,419 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,419 INFO sqlalchemy.engine.base.Engine ('2019-02-25', 3009, 241, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,421 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,422 INFO sqlalchemy.engine.base.Engine ('2019-02-26', 3014, 243, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,424 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,425 INFO sqlalchemy.engine.base.Engine ('2019-02-27', 3023, 243, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,426 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,426 INFO sqlalchemy.engine.base.Engine ('2019-02-28', 3031, 243, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,427 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,429 INFO sqlalchemy.engine.base.Engine ('2019-03-01', 3052, 244, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,430 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,431 INFO sqlalchemy.engine.base.Engine ('2019-03-02', 3060, 245, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,433 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,434 INFO sqlalchemy.engine.base.Engine ('2019-03-03', 3062, 246, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,435 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,436 INFO sqlalchemy.engine.base.Engine ('2019-03-04', 3063, 249, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,437 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,438 INFO sqlalchemy.engine.base.Engine ('2019-03-05', 3066, 252, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,440 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,441 INFO sqlalchemy.engine.base.Engine ('2019-03-06', 3071, 254, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,442 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,443 INFO sqlalchemy.engine.base.Engine ('2019-03-07', 3074, 255, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,444 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,444 INFO sqlalchemy.engine.base.Engine ('2019-03-08', 3076, 256, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,445 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,446 INFO sqlalchemy.engine.base.Engine ('2019-03-09', 3077, 258, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,447 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,448 INFO sqlalchemy.engine.base.Engine ('2019-03-10', 3080, 258, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,449 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,450 INFO sqlalchemy.engine.base.Engine ('2019-03-11', 3087, 261, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,451 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,452 INFO sqlalchemy.engine.base.Engine ('2019-03-12', 3089, 261, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,453 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,454 INFO sqlalchemy.engine.base.Engine ('2019-03-13', 3093, 262, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,455 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,456 INFO sqlalchemy.engine.base.Engine ('2019-03-14', 3098, 262, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,457 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,458 INFO sqlalchemy.engine.base.Engine ('2019-03-15', 3104, 262, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,459 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,459 INFO sqlalchemy.engine.base.Engine ('2019-03-16', 3112, 262, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,460 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,461 INFO sqlalchemy.engine.base.Engine ('2019-03-17', 3120, 262, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,462 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,462 INFO sqlalchemy.engine.base.Engine ('2019-03-18', 3131, 265, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,463 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,464 INFO sqlalchemy.engine.base.Engine ('2019-03-19', 3142, 266, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,466 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,467 INFO sqlalchemy.engine.base.Engine ('2019-03-20', 3162, 266, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,468 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,468 INFO sqlalchemy.engine.base.Engine ('2019-03-21', 3173, 268, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,469 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,470 INFO sqlalchemy.engine.base.Engine ('2019-03-22', 3180, 269, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,472 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,472 INFO sqlalchemy.engine.base.Engine ('2019-03-23', 3187, 271, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,473 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,474 INFO sqlalchemy.engine.base.Engine ('2019-03-24', 3189, 271, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,475 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,477 INFO sqlalchemy.engine.base.Engine ('2019-03-25', 3196, 274, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,478 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,479 INFO sqlalchemy.engine.base.Engine ('2019-03-26', 3212, 274, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,480 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,481 INFO sqlalchemy.engine.base.Engine ('2019-03-27', 3220, 274, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,482 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,483 INFO sqlalchemy.engine.base.Engine ('2019-03-28', 3226, 275, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,484 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,484 INFO sqlalchemy.engine.base.Engine ('2019-03-29', 3241, 275, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,485 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,486 INFO sqlalchemy.engine.base.Engine ('2019-03-30', 3253, 278, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,487 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,488 INFO sqlalchemy.engine.base.Engine ('2019-03-31', 3255, 278, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,489 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,490 INFO sqlalchemy.engine.base.Engine ('2019-04-01', 3258, 280, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,492 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,493 INFO sqlalchemy.engine.base.Engine ('2019-04-02', 3262, 282, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,494 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,495 INFO sqlalchemy.engine.base.Engine ('2019-04-03', 3264, 282, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,495 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,496 INFO sqlalchemy.engine.base.Engine ('2019-04-04', 3272, 282, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,497 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,497 INFO sqlalchemy.engine.base.Engine ('2019-04-05', 3275, 284, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,498 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,499 INFO sqlalchemy.engine.base.Engine ('2019-04-06', 3276, 287, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,500 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,501 INFO sqlalchemy.engine.base.Engine ('2019-04-07', 3279, 289, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,502 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,503 INFO sqlalchemy.engine.base.Engine ('2019-04-08', 3285, 289, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,505 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,506 INFO sqlalchemy.engine.base.Engine ('2019-04-09', 3300, 291, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,507 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,509 INFO sqlalchemy.engine.base.Engine ('2019-04-10', 3306, 293, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,511 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,512 INFO sqlalchemy.engine.base.Engine ('2019-04-11', 3312, 295, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,514 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,515 INFO sqlalchemy.engine.base.Engine ('2019-04-12', 3319, 295, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,517 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,517 INFO sqlalchemy.engine.base.Engine ('2019-04-13', 3324, 295, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,518 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,519 INFO sqlalchemy.engine.base.Engine ('2019-04-14', 3325, 297, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,520 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,520 INFO sqlalchemy.engine.base.Engine ('2019-04-15', 3329, 298, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,521 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,523 INFO sqlalchemy.engine.base.Engine ('2019-04-16', 3331, 299, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,524 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,525 INFO sqlalchemy.engine.base.Engine ('2019-04-17', 3332, 299, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,526 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,527 INFO sqlalchemy.engine.base.Engine ('2019-04-18', 3333, 299, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,528 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,528 INFO sqlalchemy.engine.base.Engine ('2019-04-19', 3336, 299, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,529 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,530 INFO sqlalchemy.engine.base.Engine ('2019-04-20', 3339, 299, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,531 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,532 INFO sqlalchemy.engine.base.Engine ('2019-04-21', 3343, 300, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,533 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,534 INFO sqlalchemy.engine.base.Engine ('2019-04-22', 3349, 302, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,535 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,536 INFO sqlalchemy.engine.base.Engine ('2019-04-23', 3357, 303, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,537 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,538 INFO sqlalchemy.engine.base.Engine ('2019-04-24', 3370, 303, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,539 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,540 INFO sqlalchemy.engine.base.Engine ('2019-04-25', 3388, 304, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,541 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,542 INFO sqlalchemy.engine.base.Engine ('2019-04-26', 3412, 304, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,543 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,544 INFO sqlalchemy.engine.base.Engine ('2019-04-27', 3437, 305, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,544 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,545 INFO sqlalchemy.engine.base.Engine ('2019-04-28', 3439, 305, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,546 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,547 INFO sqlalchemy.engine.base.Engine ('2019-04-29', 3440, 308, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,549 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,552 INFO sqlalchemy.engine.base.Engine ('2019-04-30', 3447, 309, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,553 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,554 INFO sqlalchemy.engine.base.Engine ('2019-05-01', 3466, 310, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,555 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,556 INFO sqlalchemy.engine.base.Engine ('2019-05-02', 3481, 311, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,557 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,558 INFO sqlalchemy.engine.base.Engine ('2019-05-03', 3504, 314, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,559 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,560 INFO sqlalchemy.engine.base.Engine ('2019-05-04', 3522, 317, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,561 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,562 INFO sqlalchemy.engine.base.Engine ('2019-05-05', 3527, 322, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,563 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,564 INFO sqlalchemy.engine.base.Engine ('2019-05-06', 3533, 324, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,565 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,565 INFO sqlalchemy.engine.base.Engine ('2019-05-07', 3543, 327, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,567 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,567 INFO sqlalchemy.engine.base.Engine ('2019-05-08', 3546, 328, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,568 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,569 INFO sqlalchemy.engine.base.Engine ('2019-05-09', 3555, 330, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,570 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,571 INFO sqlalchemy.engine.base.Engine ('2019-05-10', 3566, 332, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,572 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,573 INFO sqlalchemy.engine.base.Engine ('2019-05-11', 3583, 334, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,574 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,575 INFO sqlalchemy.engine.base.Engine ('2019-05-12', 3594, 335, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,576 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,577 INFO sqlalchemy.engine.base.Engine ('2019-05-13', 3614, 338, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,578 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,579 INFO sqlalchemy.engine.base.Engine ('2019-05-14', 3633, 340, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,580 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,583 INFO sqlalchemy.engine.base.Engine ('2019-05-15', 3647, 344, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,585 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,586 INFO sqlalchemy.engine.base.Engine ('2019-05-16', 3648, 349, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,587 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,588 INFO sqlalchemy.engine.base.Engine ('2019-05-17', 3649, 349, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,589 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,590 INFO sqlalchemy.engine.base.Engine ('2019-05-18', 3651, 351, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,591 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,591 INFO sqlalchemy.engine.base.Engine ('2019-05-19', 3654, 351, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,592 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,593 INFO sqlalchemy.engine.base.Engine ('2019-05-20', 3658, 354, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,595 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,595 INFO sqlalchemy.engine.base.Engine ('2019-05-21', 3671, 354, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,596 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,597 INFO sqlalchemy.engine.base.Engine ('2019-05-22', 3675, 359, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,598 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,599 INFO sqlalchemy.engine.base.Engine ('2019-05-23', 3681, 359, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,600 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,600 INFO sqlalchemy.engine.base.Engine ('2019-05-24', 3694, 361, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,601 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,602 INFO sqlalchemy.engine.base.Engine ('2019-05-25', 3699, 361, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,604 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,604 INFO sqlalchemy.engine.base.Engine ('2019-05-26', 3711, 364, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,605 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,606 INFO sqlalchemy.engine.base.Engine ('2019-05-27', 3722, 368, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,607 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,607 INFO sqlalchemy.engine.base.Engine ('2019-05-28', 3734, 373, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,608 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,609 INFO sqlalchemy.engine.base.Engine ('2019-05-29', 3766, 374, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,610 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,611 INFO sqlalchemy.engine.base.Engine ('2019-05-30', 3781, 375, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,611 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,612 INFO sqlalchemy.engine.base.Engine ('2019-05-31', 3784, 375, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,613 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,613 INFO sqlalchemy.engine.base.Engine ('2019-06-01', 3789, 378, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,614 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,614 INFO sqlalchemy.engine.base.Engine ('2019-06-02', 3790, 379, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,615 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,616 INFO sqlalchemy.engine.base.Engine ('2019-06-03', 3793, 380, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,617 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,617 INFO sqlalchemy.engine.base.Engine ('2019-06-04', 3795, 383, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,618 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,619 INFO sqlalchemy.engine.base.Engine ('2019-06-05', 3808, 385, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,619 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,620 INFO sqlalchemy.engine.base.Engine ('2019-06-06', 3830, 386, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,621 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,622 INFO sqlalchemy.engine.base.Engine ('2019-06-07', 3843, 387, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,623 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,624 INFO sqlalchemy.engine.base.Engine ('2019-06-08', 3857, 390, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,627 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,628 INFO sqlalchemy.engine.base.Engine ('2019-06-09', 3870, 394, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,629 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,630 INFO sqlalchemy.engine.base.Engine ('2019-06-10', 3895, 395, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,632 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,633 INFO sqlalchemy.engine.base.Engine ('2019-06-11', 3919, 397, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,635 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,635 INFO sqlalchemy.engine.base.Engine ('2019-06-12', 3942, 399, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,637 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,638 INFO sqlalchemy.engine.base.Engine ('2019-06-13', 3983, 402, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,640 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,641 INFO sqlalchemy.engine.base.Engine ('2019-06-14', 4022, 404, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,643 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,643 INFO sqlalchemy.engine.base.Engine ('2019-06-15', 4053, 409, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,644 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,645 INFO sqlalchemy.engine.base.Engine ('2019-06-16', 4058, 410, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,646 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,646 INFO sqlalchemy.engine.base.Engine ('2019-06-17', 4063, 414, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,647 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,648 INFO sqlalchemy.engine.base.Engine ('2019-06-18', 4064, 417, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,649 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,650 INFO sqlalchemy.engine.base.Engine ('2019-06-19', 4065, 422, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,650 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,651 INFO sqlalchemy.engine.base.Engine ('2019-06-20', 4066, 424, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,652 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,653 INFO sqlalchemy.engine.base.Engine ('2019-06-21', 4069, 425, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,654 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,655 INFO sqlalchemy.engine.base.Engine ('2019-06-22', 4070, 426, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,656 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,657 INFO sqlalchemy.engine.base.Engine ('2019-06-23', 4073, 427, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,658 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,658 INFO sqlalchemy.engine.base.Engine ('2019-06-24', 4084, 427, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,659 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,660 INFO sqlalchemy.engine.base.Engine ('2019-06-25', 4108, 427, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,661 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,661 INFO sqlalchemy.engine.base.Engine ('2019-06-26', 4122, 433, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,662 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,663 INFO sqlalchemy.engine.base.Engine ('2019-06-27', 4132, 436, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,664 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,664 INFO sqlalchemy.engine.base.Engine ('2019-06-28', 4150, 440, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,665 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,666 INFO sqlalchemy.engine.base.Engine ('2019-06-29', 4162, 440, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,667 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,669 INFO sqlalchemy.engine.base.Engine ('2019-06-30', 4164, 446, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,674 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,675 INFO sqlalchemy.engine.base.Engine ('2019-07-01', 4167, 448, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,676 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,677 INFO sqlalchemy.engine.base.Engine ('2019-07-02', 4174, 450, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,678 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,679 INFO sqlalchemy.engine.base.Engine ('2019-07-03', 4179, 455, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,681 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,681 INFO sqlalchemy.engine.base.Engine ('2019-07-04', 4187, 456, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,682 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,683 INFO sqlalchemy.engine.base.Engine ('2019-07-05', 4200, 456, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,684 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,684 INFO sqlalchemy.engine.base.Engine ('2019-07-06', 4210, 458, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,685 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,686 INFO sqlalchemy.engine.base.Engine ('2019-07-07', 4211, 458, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,688 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,689 INFO sqlalchemy.engine.base.Engine ('2019-07-08', 4214, 464, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,690 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,691 INFO sqlalchemy.engine.base.Engine ('2019-07-09', 4219, 464, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,692 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,693 INFO sqlalchemy.engine.base.Engine ('2019-07-10', 4223, 468, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,694 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,695 INFO sqlalchemy.engine.base.Engine ('2019-07-11', 4228, 469, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,696 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,696 INFO sqlalchemy.engine.base.Engine ('2019-07-12', 4236, 469, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,698 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,698 INFO sqlalchemy.engine.base.Engine ('2019-07-13', 4239, 471, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,699 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,700 INFO sqlalchemy.engine.base.Engine ('2019-07-14', 4243, 471, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,701 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,701 INFO sqlalchemy.engine.base.Engine ('2019-07-15', 4250, 473, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,702 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,703 INFO sqlalchemy.engine.base.Engine ('2019-07-16', 4265, 476, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,704 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,705 INFO sqlalchemy.engine.base.Engine ('2019-07-17', 4288, 476, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,706 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,706 INFO sqlalchemy.engine.base.Engine ('2019-07-18', 4313, 483, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,707 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,708 INFO sqlalchemy.engine.base.Engine ('2019-07-19', 4329, 483, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,709 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,709 INFO sqlalchemy.engine.base.Engine ('2019-07-20', 4329, 486, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,710 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,711 INFO sqlalchemy.engine.base.Engine ('2019-07-21', 4329, 487, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,711 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,712 INFO sqlalchemy.engine.base.Engine ('2019-07-22', 4333, 492, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,713 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,713 INFO sqlalchemy.engine.base.Engine ('2019-07-23', 4335, 493, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:41,714 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:41,715 INFO sqlalchemy.engine.base.Engine ('2019-07-24', 4353, 494, '2020-10-21 22:06:39.532225')
# ...
# 2020-10-21 22:06:42,622 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,623 INFO sqlalchemy.engine.base.Engine ('2020-08-20', 8767, 1424, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,625 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,626 INFO sqlalchemy.engine.base.Engine ('2020-08-21', 8784, 1426, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,627 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,629 INFO sqlalchemy.engine.base.Engine ('2020-08-22', 8793, 1426, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,630 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,630 INFO sqlalchemy.engine.base.Engine ('2020-08-23', 8808, 1426, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,631 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,632 INFO sqlalchemy.engine.base.Engine ('2020-08-24', 8825, 1429, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,633 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,633 INFO sqlalchemy.engine.base.Engine ('2020-08-25', 8835, 1439, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,634 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,634 INFO sqlalchemy.engine.base.Engine ('2020-08-26', 8857, 1443, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,635 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,636 INFO sqlalchemy.engine.base.Engine ('2020-08-27', 8883, 1444, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,637 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,639 INFO sqlalchemy.engine.base.Engine ('2020-08-28', 8916, 1445, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,641 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,641 INFO sqlalchemy.engine.base.Engine ('2020-08-29', 8922, 1447, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,643 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,644 INFO sqlalchemy.engine.base.Engine ('2020-08-30', 8925, 1450, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,645 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,647 INFO sqlalchemy.engine.base.Engine ('2020-08-31', 8928, 1451, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,649 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,650 INFO sqlalchemy.engine.base.Engine ('2020-09-01', 8932, 1457, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,651 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,652 INFO sqlalchemy.engine.base.Engine ('2020-09-02', 8939, 1459, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,653 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,654 INFO sqlalchemy.engine.base.Engine ('2020-09-03', 8940, 1460, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,656 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,657 INFO sqlalchemy.engine.base.Engine ('2020-09-04', 8956, 1460, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,658 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,659 INFO sqlalchemy.engine.base.Engine ('2020-09-05', 8966, 1460, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,661 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,662 INFO sqlalchemy.engine.base.Engine ('2020-09-06', 8972, 1461, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,663 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,664 INFO sqlalchemy.engine.base.Engine ('2020-09-07', 8978, 1465, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,666 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,667 INFO sqlalchemy.engine.base.Engine ('2020-09-09', 8986, 1467, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,668 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,669 INFO sqlalchemy.engine.base.Engine ('2020-09-10', 8989, 1470, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,670 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,671 INFO sqlalchemy.engine.base.Engine ('2020-09-11', 8991, 1471, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,673 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,675 INFO sqlalchemy.engine.base.Engine ('2020-09-12', 8995, 1473, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,676 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,678 INFO sqlalchemy.engine.base.Engine ('2020-09-13', 9000, 1474, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,679 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,680 INFO sqlalchemy.engine.base.Engine ('2020-09-14', 9002, 1476, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,682 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,683 INFO sqlalchemy.engine.base.Engine ('2020-09-15', 9022, 1477, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,846 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,846 INFO sqlalchemy.engine.base.Engine ('2020-09-16', 9030, 1478, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,847 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,848 INFO sqlalchemy.engine.base.Engine ('2020-09-16', 9030, 1478, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,849 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,849 INFO sqlalchemy.engine.base.Engine ('2020-09-16', 9030, 1478, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,850 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,851 INFO sqlalchemy.engine.base.Engine ('2020-09-16', 9030, 1478, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,852 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,853 INFO sqlalchemy.engine.base.Engine ('2020-09-16', 9030, 1478, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,854 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,856 INFO sqlalchemy.engine.base.Engine ('2020-09-17', 9044, 1481, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,858 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,859 INFO sqlalchemy.engine.base.Engine ('2020-09-18', 9059, 1484, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,861 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,862 INFO sqlalchemy.engine.base.Engine ('2020-09-19', 9062, 1486, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,863 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,864 INFO sqlalchemy.engine.base.Engine ('2020-09-20', 9063, 1489, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,865 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,865 INFO sqlalchemy.engine.base.Engine ('2020-09-21', 9065, 1492, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,867 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,870 INFO sqlalchemy.engine.base.Engine ('2020-09-22', 9066, 1494, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,872 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,874 INFO sqlalchemy.engine.base.Engine ('2020-09-23', 9068, 1495, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,875 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,877 INFO sqlalchemy.engine.base.Engine ('2020-09-24', 9073, 1495, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,879 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,880 INFO sqlalchemy.engine.base.Engine ('2020-09-25', 9076, 1495, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,880 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,881 INFO sqlalchemy.engine.base.Engine ('2020-09-26', 9079, 1499, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,882 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,883 INFO sqlalchemy.engine.base.Engine ('2020-09-27', 9085, 1501, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,885 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,886 INFO sqlalchemy.engine.base.Engine ('2020-09-28', 9089, 1501, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,887 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,888 INFO sqlalchemy.engine.base.Engine ('2020-09-29', 9100, 1502, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,890 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,891 INFO sqlalchemy.engine.base.Engine ('2020-09-30', 9111, 1505, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,892 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,893 INFO sqlalchemy.engine.base.Engine ('2020-10-01', 9127, 1507, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,895 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,896 INFO sqlalchemy.engine.base.Engine ('2020-10-02', 9140, 1515, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,897 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,898 INFO sqlalchemy.engine.base.Engine ('2020-10-03', 9142, 1516, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,900 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,901 INFO sqlalchemy.engine.base.Engine ('2020-10-04', 9151, 1517, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,902 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,903 INFO sqlalchemy.engine.base.Engine ('2020-10-05', 9156, 1518, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,904 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,905 INFO sqlalchemy.engine.base.Engine ('2020-10-06', 9170, 1519, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,909 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,911 INFO sqlalchemy.engine.base.Engine ('2020-10-07', 9190, 1521, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,913 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,914 INFO sqlalchemy.engine.base.Engine ('2020-10-08', 9194, 1522, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,915 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,916 INFO sqlalchemy.engine.base.Engine ('2020-10-09', 9197, 1526, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,918 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,919 INFO sqlalchemy.engine.base.Engine ('2020-10-10', 9200, 1526, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,919 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,920 INFO sqlalchemy.engine.base.Engine ('2020-10-11', 9204, 1528, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,921 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,923 INFO sqlalchemy.engine.base.Engine ('2020-10-12', 9214, 1531, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,924 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,925 INFO sqlalchemy.engine.base.Engine ('2020-10-13', 9220, 1536, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,926 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,928 INFO sqlalchemy.engine.base.Engine ('2020-10-14', 9248, 1540, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,929 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,929 INFO sqlalchemy.engine.base.Engine ('2020-10-15', 9265, 1540, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,931 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,931 INFO sqlalchemy.engine.base.Engine ('2020-10-16', 9297, 1542, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,933 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,936 INFO sqlalchemy.engine.base.Engine ('2020-10-17', 9300, 1546, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,937 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-10-21 22:06:42,938 INFO sqlalchemy.engine.base.Engine ('2020-10-18', 9312, 1547, '2020-10-21 22:06:39.532225')
# 2020-10-21 22:06:42,958 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
def read_data():

    from assets import models
    df = pd.read_csv('assets/data.csv')
    for index, _df in df.iterrows():
        date = datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
        row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
        db_session.add(row)
    db_session.commit()
